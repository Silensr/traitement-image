# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage import data

# %%
image_hand = plt.imread('./images/hand.JPG') 
print(image_hand)
np.shape(image_hand)
# Out:
# [[[ 88  88  88]
#   [ 93  93  93]
#   [ 94  94  94]
#   ...
#   [ 91  91  91]
#   [ 79  79  79]
#   [255 255 255]]
#
#  [[ 27  27  27]
#   [ 33  33  33]
#   [ 35  35  35]
#   ...
#   [ 43  43  43]
#   [ 40  40  40]
#   [234 234 234]]
#
#  [[ 39  39  39]
#   [ 43  43  43]
#   [ 43  43  43]
#   ...
#   [ 38  38  38]
#   [ 38  38  38]
#   [237 237 237]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 71  71  71]
#   [ 71  71  71]
#   [243 243 243]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [ 83  83  83]
#   [ 97  97  97]
#   [230 230 230]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [240 240 240]
#   [233 233 233]
#   [255 255 255]]]
# (276, 414, 3)

# %%
plt.imshow(image_hand)

# %%
A = np.zeros( (10,20), dtype = np.uint8)

B = np.copy(A)

C = np.array([
    [1,2],
    [3,4],
    [5,6]
], dtype= np.Uint64)

plt.imshow(A)

# %%
plt.imshow(C)

# %%
red = [255, 0, 0]
white = [255, 255, 255]
blue = [0,0, 255]

france_flag = np.array([[blue, white, red], [blue, white, red]])

plt.imshow(france_flag)
