# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage import data

# %%
image_lena = plt.imread('./images/lena512color.tiff') 
print(image_lena)
np.shape(image_lena)
# Out:
# [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]
# (512, 512, 3)

# %%
plt.imshow(image_lena)

# %%
A = np.zeros( (10,20), dtype = np.uint8)

B = np.copy(A)

C = np.array([
    [1,2],
    [3,4],
    [5,6]
], dtype= np.Uint64)

plt.imshow(A)

# %%
plt.imshow(C)

# %%
red = [255, 0, 0]
white = [255, 255, 255]
blue = [0,0, 255]

france_flag = np.array([[blue, white, red], [blue, white, red]])

plt.imshow(france_flag)

# %%
def quadrant(image, i, j):

    x, y, _  = np.shape(image)
    x /= 2
    y /= 2

    print(int(x) * (i-1),int(x) * i, int(y) * (j-1), int(y) * j)

    return image[int(x) * (i-1): int(x) * i, int(y) * (j-1) : int(y) * j]
plt.imshow(quadrant(image_lena,1,1))
# Out:
# 0 256 0 256

# %%
plt.imshow(quadrant(image_lena,1,2))
# Out:
# 0 256 256 512

# %%
plt.imshow(quadrant(image_lena, 2, 1))
# Out:
# 256 512 0 256

# %%
plt.imshow(quadrant(image_lena, 2, 2))
# Out:
# 256 512 256 512

# %%
def symetrie(image):

    return np.fliplr(image)

plt.imshow(symetrie(image_lena))

# %%
def rotation(image):
    return np.rot90(image,3)

plt.imshow(rotation(image_lena))

# %%
def composante(image, k):

    x,y,z = np.shape(image)

    new_image = np.copy(image)

    for i in range(x):
        for j in range(y):

            new_image[i,j,k-1] = 0
    
    return new_image

plt.imshow(composante(image_lena, 1))

# %%
plt.imshow(composante(image_lena,2))

# %%
plt.imshow(composante(image_lena,3))

# %%
def primaire(image, k):

    x,y,z = np.shape(image)

    new_image = np.copy(image)

    for i in range(x):
        for j in range(y):

            if k == 1:
                new_image[i,j,1], new_image[i,j,2] = 0,0
            
            elif k == 2:
                new_image[i,j,0], new_image[i,j,2] = 0, 0
            
            elif k == 3:
                new_image[i,j,0], new_image[i,j,1] = 0,0
    
 

    return new_image

plt.imshow(primaire(image_lena,1))

# %%
plt.imshow(primaire(image_lena,2))

# %%
plt.imshow(primaire(image_lena,3))

# %%
def to_grey(image):

    rlevel = primaire(image, 1) * 299/1000
    glevel = primaire(image, 2) * 587/1000
    blevel = primaire(image, 3) * 114/1000

    return rlevel + glevel + blevel

plt.imshow(to_grey(image_lena), cmap="gray")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
a = np.array([[1,2],[3,4]])

a*3
# Out:
# array([[ 3,  6],
#        [ 9, 12]])
